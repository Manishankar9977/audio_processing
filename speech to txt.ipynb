# %% [markdown]
# SPEECH TO TEXT  USING AUDIO FILE
# In ENGLISH

# %%
# !pip3 install SpeechRecognition pydub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 32.8 MB 1.4 MB/s
# ...

# %%
import speech_recognition as sr

# %%
filename = "machine-learning_speech-recognition_16-122828-0002.wav"

# %%
import IPython.display as ipd
(ipd.Audio(filename))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# initialize the recognizer
r = sr.Recognizer()

# %%
# open the file
with sr.AudioFile(filename) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    print(text)
# Out:
# I believe you're just talking nonsense

# %% [markdown]
# USING MICROPHONE

# %%
# !apt install build-ess ential portaudio19-dev
# !pip install pyaudio
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package build-ess
# E: Unable to locate package ential
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 42 kB 1.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# ERROR: Could not build wheels for pyaudio which use PEP 517 and cannot be installed directly

# %%
sr.Microphone.list_microphone_names()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/speech_recognition/__init__.py in get_pyaudio()
#     107         try:
# --> 108             import pyaudio
#     109         except ImportError:
#
# ModuleNotFoundError: No module named 'pyaudio'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-a77fd978dec0> in <module>
# ----> 1 sr.Microphone.list_microphone_names()
#
# /usr/local/lib/python3.7/dist-packages/speech_recognition/__init__.py in list_microphone_names()
#     121         The index of each microphone's name is the same as its device index when creating a ``Microphone`` instance - indices in this list can be used as values of ``device_index``.
#     122         """
# ...

# %%
with sr.Microphone() as source:
    # listen for the data (load audio to memory)
    audio_data = r.listen(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    print(text)

# %% [markdown]
# SPEECH TO TEXT USING AUDIO FILE  IN HINDI

# %%
file="Recording (4).wav"

# %%
# open the file
with sr.AudioFile(file) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data,language='hi-In')
    print(text)
# Out:
# नमस्ते मेरा नाम मनीष है

# %%
with sr.Microphone() as source:
    # listen for the data (load audio to memory)
    audio_data = r.listen(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data,audio_data,language='hi-In')
    print(text)
